# %%
from pyspark.sql.types import  StringType, IntegerType
from pyspark.sql.functions import col
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
{"timestamp": "1571053218000","t1": "55.23","t2": "10","t3": "ON"},
{"timestamp": "1571053278000","t1": "63.23","t2": "11","t3": "OFF"},
{"timestamp": "1571053338000","t1": "73.23","t2": "12","t3": "ON"},
{"timestamp": "1571053398000","t1": "83.23","t2": "13","t3": "ON"}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[147]: {&#39;timestamp&#39;: &#39;1571053398000&#39;, &#39;t1&#39;: &#39;83.23&#39;, &#39;t2&#39;: &#39;13&#39;, &#39;t3&#39;: &#39;ON&#39;}</div>

# %%
data = spark.read.format("json").load("/FileStore/tables/topgear/test.json")

data= data.withColumn("t1",col("t1").cast("Integer")) \
  .withColumn("t2",col("t2").cast("Integer")) \
  .withColumn("t3",col("t3").cast("String")) \
  .withColumn("timestamp",col("timestamp").cast("String"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+---+---+-------------+
#  t1| t2| t3|    timestamp|
# +---+---+---+-------------+
#  55| 10| ON|1571053218000|
#  63| 11|OFF|1571053278000|
#  73| 12| ON|1571053338000|
#  83| 13| ON|1571053398000|
# +---+---+---+-------------+
#
# </div>

# %%
from pyspark.sql.functions import col


data1 = data.select(col("t1"),col("timestamp"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rule_def ={"t1" :[">",50,4],
           "t2":[">",20,6],
           "t3":["=","ON",3]}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import lit,row_number,col
from pyspark.sql.window import Window
w = Window().orderBy("t1")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data2 = data1.withColumn("row_num", row_number().over(w))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lenn =int( (data2.count())/conce)
rul_id =1
exp = rule_def["t1"][1]
conce = rule_def["t1"][2]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
for i in range(0,lenn):
  ct=data2.filter( (data2.t1  > exp) & (col("row_num").between(st,en)) ).count()
  print(ct,conce)
  if ct == conce:
    data2.filter(data2.row_num == 4).select(data2.timestamp).withColumn("ruleid",lit(rul_id)).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">4 4
# +-------------+------+
#     timestamp|ruleid|
# +-------------+------+
# 1571053398000|     1|
# +-------------+------+
#
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
